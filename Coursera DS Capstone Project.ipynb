# %% [markdown]
# ## Data Science Coursera Capstone Project
#
# ___

# %% [markdown]
# ##### Welcome to this Notebook.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![WORK IN PROGRESS.png](attachment:f5630b5a-8026-42f9-bf5c-5132d3ffb322.png)
